# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Data_files/Kaggle"
# /content/gdrive/My Drive/Data_files/Kaggle is the path where kaggle.json is present in the Google Drive

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Data_files/Kaggle
#Check the present working directory using pwd command
# Out:
# /content/gdrive/My Drive/Data_files/Kaggle

# %%
# %pwd
# Out:
# '/content/gdrive/My Drive/Data_files/Kaggle'

# %%
# !kaggle competitions download -c bioresponse
# Out:
# ...
#   0% 0.00/2.71M [00:00<?, ?B/s]
# 100% 2.71M/2.71M [00:00<00:00, 44.6MB/s]
# ...
#   0% 0.00/35.2k [00:00<?, ?B/s]
# 100% 35.2k/35.2k [00:00<00:00, 5.47MB/s]
# ...
#   0% 0.00/1.80M [00:00<?, ?B/s]
# 100% 1.80M/1.80M [00:00<00:00, 58.3MB/s]
